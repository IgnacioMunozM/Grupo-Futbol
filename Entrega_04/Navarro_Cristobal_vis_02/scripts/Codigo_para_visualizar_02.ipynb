# %%
from IPython.display import HTML

html_code = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Generación Dorada del Fútbol de Chile</title>
    <style>
        /* styles.css */
body {
    font-family: Arial, sans-serif;
    background-color: lightblue;
    color: #333;
    margin: 0;
    padding: 0;
}

h1 {
    text-align: center;
    font-size: 2em;
    margin-top: 20px;
}

ul {
    list-style: none;
    padding: 0;
    text-align: center;
}

ul li {
    margin: 10px 0;
    transition: font-size 0.3s;
    position: relative;
}

ul li:hover::after {
    content: attr(data-partidos) " partidos jugados";
    position: absolute;
    left: 50%;
    transform: translateX(-50%);
    top: 100%;
    background-color: #fff;
    padding: 5px;
    border: 1px solid #ccc;
    border-radius: 5px;
    white-space: nowrap;
    z-index: 1;
}
    </style>
</head>
<body>
    <h1>Generación Dorada</h1>
    <ul id="jugadores">
        <li data-partidos="60">Mauricio Isla</li>
        <li data-partidos="60">Alexis Sánchez</li>
        <li data-partidos="59">Gary Medel</li>
        <li data-partidos="56">Arturo Vidal</li>
        <li data-partidos="53">Charles Aránguiz</li>
        <li data-partidos="53">Eduardo Vargas</li>
        <li data-partidos="49">Claudio Bravo</li>
        <li data-partidos="34">Jean Beausejour</li>
        <li data-partidos="32">Gonzalo Jara</li>
        <li data-partidos="25">Marcelo Díaz</li>
        <li data-partidos="25">Eugenio Mena</li>
        <li data-partidos="21">José Pedro Fuenzalida</li>
        <li data-partidos="17">Francisco Silva</li>
        <li data-partidos="15">Jorge Valdivia</li>
        <li data-partidos="8">Matías Fernández</li>
    </ul>

    <h1>Recambio Estable</h1>
    <ul id="otros-jugadores">
        <li data-partidos="30">Erick Pulgar</li>
        <li data-partidos="25">Guillermo Maripán</li>
        <li data-partidos="10">Brayan Cortés, arquero</li>
        <li data-partidos="10">Marcelino Nuñez</li>
        <li data-partidos="12">Gabriel Suazo</li>
    </ul>

    <h1>Recambio fallido</h1>
    <ul id="otros-jugadores">
        <li data-partidos="17">Enzo Roco</li>
        <li data-partidos="16">Jean Meneses</li>
        <li data-partidos="11">Diego Valdés</li>
        <li data-partidos="11">Claudio Baeza</li>
        <li data-partidos="10">Edson Puch</li>
        <li data-partidos="9">Mauricio Pinilla</li>
        <li data-partidos="9">Felipe Gutiérrez</li>
        <li data-partidos="9">Nicolás Castillo</li>
        <li data-partidos="8">Tomás Alarcón</li>
        <li data-partidos="8">César Pinares</li>
        <li data-partidos="8">Francisco Sierralta</li>
        <li data-partidos="8">Sebastián Vegas</li>
        <li data-partidos="7">Gabriel Arias</li>
        <li data-partidos="7">Rodrigo Echeverría</li>
        <li data-partidos="6">Carlos Palacios</li>
        <li data-partidos="6">Pablo Galdames</li>
        <li data-partidos="6">Luís Jiménez</li>
        <li data-partidos="6">Joaquín Montecinos</li>
        <li data-partidos="5">Alexander Aravena</li>
        <li data-partidos="5">Leonardo Valencia</li>
        <li data-partidos="5">Mark González</li>
        <li data-partidos="5">Esteban Paredes</li>
        <li data-partidos="4">Johnny Herrera</li>
        <li data-partidos="4">Martín Rodríguez</li>
        <li data-partidos="4">Nicolás Díaz</li>
        <li data-partidos="4">Víctor Dávila</li>
        <li data-partidos="4">Felipe Mora</li>
        <li data-partidos="3">Víctor Felipe Méndez</li>
        <li data-partidos="3">Felipe Loyola</li>
        <li data-partidos="3">Junior Fernandez</li>
        <li data-partidos="2">Benjamín Kusevic</li>
        <li data-partidos="2">Ronnie Fernández</li>
        <li data-partidos="2">Dario Osorio</li>
        <li data-partidos="2">Juan Delgado</li>
        <li data-partidos="2">Angelo Sagal</li>
        <li data-partidos="2">Miiko Albornoz</li>
        <li data-partidos="2">Angelo Henríquez</li>
        <li data-partidos="2">Óscar Opazo</li>
        <li data-partidos="2">Esteban Pavez</li>
        <li data-partidos="2">Diego Valencia</li>
        <li data-partidos="2">Christopher Toselli</li>
        <li data-partidos="2">Iván Morales</li>
        <li data-partidos="1">Valber Huerta</li>
        <li data-partidos="1">Pablo Parra</li>
        <li data-partidos="1">Nayel Mehssatou</li>
        <li data-partidos="1">Damian Pizarro</li>
        <li data-partidos="1">Matías Fernández C.</li>
        <li data-partidos="1">Maximiliano Guerrero</li>
        <li data-partidos="1">Vicente Pizarro</li>
        <li data-partidos="1">César Pérez</li>
        <li data-partidos="1">Igor Lichnovsky</li>
        <li data-partidos="1">Pablo Aranguíz</li>
        <li data-partidos="1">Luciano Arriagada</li>
        <li data-partidos="1">Christian Vilches</li>
        <li data-partidos="1">Bryan Rabello</li>
        <li data-partidos="1">Rodrigo Millar</li>
        <li data-partidos="1">Carlos Carmona</li>
        <li data-partidos="1">Yonathan Andía</li>
        <li data-partidos="1">Niklas Castro</li>
        <li data-partidos="1">Andrés Vilches</li>
    </ul>

    <script>
        // scripts.js
document.addEventListener('DOMContentLoaded', function() {
    const jugadores = document.querySelectorAll('ul li');

    jugadores.forEach(jugador => {
        const partidos = parseInt(jugador.getAttribute('data-partidos'), 10);
        const fontSize = calcularTamañoFuente(partidos);
        jugador.style.fontSize = `${fontSize}px`;
    });
});

function calcularTamañoFuente(partidos) {
    const minPartidos = 1;  // Número mínimo de partidos jugados
    const maxPartidos = 65; // Número máximo de partidos jugados
    const minFontSize = 12;  // Tamaño mínimo de fuente en px
    const maxFontSize = 55;  // Tamaño máximo de fuente en px

    // Asegurarse de que los partidos estén dentro del rango esperado
    const partidosClamped = Math.max(minPartidos, Math.min(maxPartidos, partidos));

    // Calcular el tamaño de fuente correspondiente
    const fontSize = minFontSize + (partidosClamped - minPartidos) * (maxFontSize - minFontSize) / (maxPartidos - minPartidos);
    return fontSize;
}
    </script>
</body>
</html>
"""

HTML(html_code)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Generación Dorada del Fútbol de Chile</title>
#     <style>
#         /* styles.css */
# body {
#     font-family: Arial, sans-serif;
#     background-color: lightblue;
#     color: #333;
#     margin: 0;
#     padding: 0;
# }
#
# h1 {
#     text-align: center;
#     font-size: 2em;
#     margin-top: 20px;
# }
#
# ul {
#     list-style: none;
#     padding: 0;
#     text-align: center;
# }
#
# ul li {
#     margin: 10px 0;
#     transition: font-size 0.3s;
#     position: relative;
# }
#
# ul li:hover::after {
#     content: attr(data-partidos) " partidos jugados";
#     position: absolute;
#     left: 50%;
#     transform: translateX(-50%);
#     top: 100%;
#     background-color: #fff;
#     padding: 5px;
#     border: 1px solid #ccc;
#     border-radius: 5px;
#     white-space: nowrap;
#     z-index: 1;
# }
# ...
